# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\rwanda_transport_sentiment_dataset_cleaned.csv")
df
# Out:
#    Observation ID        Date           Source   Location     Commuter Type  \
# 0          OBS001  2025-05-02   WhatsApp Group     Kigali           Student
# 1          OBS002  2025-05-16   WhatsApp Group     Rubavu           Student
# 2          OBS003  2025-05-05  YouTube Comment     Kigali  University Staff
# 3          OBS004  2025-05-07  YouTube Comment  Nyagatare            Parent
# 4          OBS005  2025-05-01   WhatsApp Group     Rubavu  University Staff
# ..            ...         ...              ...        ...               ...
# 95         OBS096  2025-05-10    Radio Call-in     Rusizi           Unknown
# 96         OBS097  2025-05-02   WhatsApp Group     Kigali            Trader
# 97         OBS098  2025-05-15          Twitter    Musanze            Trader
# 98         OBS099  2025-05-12  YouTube Comment     Kigali            Trader
# 99         OBS100  2025-05-06  YouTube Comment    Muhanga      Daily Worker
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Observation ID           100 non-null    object
#  1   Date                     100 non-null    object
#  2   Source                   100 non-null    object
#  3   Location                 100 non-null    object
#  4   Commuter Type            100 non-null    object
#  5   Sentiment                100 non-null    object
#  6   Emotion                  100 non-null    object
#  7   Key Concern              100 non-null    object
#  8   Misinformation (Yes/No)  100 non-null    object
#  9   Key Quote/Comment        100 non-null    object
#  10  Suggestion Given         100 non-null    object
#  11  Observer's Notes         100 non-null    object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %%
df.describe()
# Out:
#        Observation ID        Date    Source Location Commuter Type Sentiment  \
# count             100         100       100      100           100       100
# unique            100          15         5        8             6         4
# top            OBS001  2025-05-07  Facebook   Rusizi  Daily Worker  Positive
# freq                1          11        24       18            23        30
#
#                Emotion                      Key Concern  \
# count              100                              100
# unique               6                                6
# top     Disappointment  Fair pricing for long distances
# freq                25                               21
#
#        Misinformation (Yes/No)                 Key Quote/Comment  \
# count                      100                               100
# unique                       2                                 6
# top                        Yes  fair pricing for long distances.
# ...

# %%
df.head()
# Out:
#   Observation ID        Date           Source   Location     Commuter Type  \
# 0         OBS001  2025-05-02   WhatsApp Group     Kigali           Student
# 1         OBS002  2025-05-16   WhatsApp Group     Rubavu           Student
# 2         OBS003  2025-05-05  YouTube Comment     Kigali  University Staff
# 3         OBS004  2025-05-07  YouTube Comment  Nyagatare            Parent
# 4         OBS005  2025-05-01   WhatsApp Group     Rubavu  University Staff
#
#   Sentiment         Emotion                         Key Concern  \
# 0  Positive  Disappointment     Fair pricing for long distances
# 1  Positive    Satisfaction  Increased cost for short distances
# 2  Positive           Anger              Unclear fare structure
# 3  Positive  Disappointment     Fair pricing for long distances
# 4     Mixed       Confusion  Increased cost for short distances
#
#   Misinformation (Yes/No)                    Key Quote/Comment  \
# ...

# %%
df.isnull().sum()
# Out:
# Observation ID             0
# Date                       0
# Source                     0
# Location                   0
# Commuter Type              0
# Sentiment                  0
# Emotion                    0
# Key Concern                0
# Misinformation (Yes/No)    0
# Key Quote/Comment          0
# Suggestion Given           0
# Observer's Notes           0
# dtype: int64

# %%
df.dropna()
# Out:
#    Observation ID        Date           Source   Location     Commuter Type  \
# 0          OBS001  2025-05-02   WhatsApp Group     Kigali           Student
# 1          OBS002  2025-05-16   WhatsApp Group     Rubavu           Student
# 2          OBS003  2025-05-05  YouTube Comment     Kigali  University Staff
# 3          OBS004  2025-05-07  YouTube Comment  Nyagatare            Parent
# 4          OBS005  2025-05-01   WhatsApp Group     Rubavu  University Staff
# ..            ...         ...              ...        ...               ...
# 95         OBS096  2025-05-10    Radio Call-in     Rusizi           Unknown
# 96         OBS097  2025-05-02   WhatsApp Group     Kigali            Trader
# 97         OBS098  2025-05-15          Twitter    Musanze            Trader
# 98         OBS099  2025-05-12  YouTube Comment     Kigali            Trader
# 99         OBS100  2025-05-06  YouTube Comment    Muhanga      Daily Worker
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df, x='Sentiment', hue='Sentiment', palette='coolwarm', legend=False)
plt.title("Public Sentimeter on Distance_Based Fare System")
plt.xlabel("Sentiment")
plt.ylabel("Number of Observation")
plt.show()

# %%
plt.figure(figsize=(8,5))
emotion_count = df['Emotion'].value_counts().reset_index()
emotion_count.columns = ['Emotion', 'Count']
sns.barplot(data=emotion_count, x='Emotion', y='Count')  # Removed palette='muted'
plt.title('Emotion Frequencies')
plt.ylabel('Count')
plt.xlabel('Emotion')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
concern_location = df.groupby(['Location', 'Key Concern']).size().reset_index(name='counts')
top_concerns = df['Key Concern'].value_counts().nlargest(5).index
filtered = concern_location[concern_location['Key Concern'].isin(top_concerns)]
sns.barplot(data=filtered, x='Location', y='counts', hue='Key Concern')
plt.title('Top Key Concerns by Location')
plt.ylabel('Number of Comments')
plt.xlabel('Location')
plt.legend(title='Key Concern')
plt.show()

# %%
commuter_sentiment = df.groupby(['Commuter Type', 'Sentiment']).size().unstack(fill_value=0)
commuter_sentiment_percent = commuter_sentiment.div(commuter_sentiment.sum(axis=1), axis=0)

commuter_sentiment_percent.plot(kind='bar', stacked=True, figsize=(10,6), colormap='tab20')
plt.title('Sentiment Distribution by Commuter Type')
plt.ylabel('Proportion of Comments')
plt.xlabel('Commuter Type')
plt.legend(title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 5))
misinfo_time.plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Misinformation Comments Over Time')
plt.ylabel('Number of Comments')
plt.xlabel('Date')
plt.legend(title='Misinformation')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
